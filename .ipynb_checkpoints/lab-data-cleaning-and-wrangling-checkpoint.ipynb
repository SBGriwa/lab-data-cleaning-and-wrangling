# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/Users/civicfab/Desktop/Documents/Ironhack/Unit4/labs/lab-cleaning-categorical-data/files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
data.columns = [data.columns[i].lower().replace(' ', '_') for i in range(len(data.columns)) ]
data.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
data = data.drop(['customer'], axis=1)
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
data['effective_to_date']
# Out:
# 0       2/24/11
# 1       1/31/11
# 2       2/19/11
# 3       1/20/11
# 4        2/3/11
#          ...
# 9129    2/10/11
# 9130    2/12/11
# 9131     2/6/11
# 9132     2/3/11
# 9133    2/14/11
# Name: effective_to_date, Length: 9134, dtype: object

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'], errors='coerce')
data['effective_to_date']
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %% [markdown]
# # Open the categoricals variable we created before

# %%
categoricals = data.select_dtypes('object')
categoricals.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# ...

# %% [markdown]
# # Plot all the categorical variables with the proper plot. What can you see?

# %%
for column in categoricals.columns:
    plt.figure(figsize=(10,4))
    sns.barplot(x=column, y="total_claim_amount", data=data)
    plt.show()

# %% [raw]
# 1- premium coverage resulst in more total_claim_amount
# 2- doctors have lowest total_claim_amount
# 3- employed people have lowest total_claim_amount
# 4- people who lives in rural areas have lowest total_claim_amount
# 5- singles have highest total_claim_amoun compared to divorced or married people
# 7- people who own two or four-door cars have lowest total_claim_amount

# %% [markdown]
# # There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %%
for column in categoricals.columns:
    print(data[column].value_counts())
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
# No     7826
# Yes    1308
# Name: response, dtype: int64
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
# F    4658
# M    4476
# Name: gender, dtype: int64
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
# Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64
# Personal L3     3426
# ...

# %%
categoricals["coverage"] = categoricals["coverage"].map({"Basic" : 0, "Extended" : 1, "Premium" : 2}).astype(int)

# %%
categoricals["vehicle_size"] = categoricals["vehicle_size"].map({"Small" : 1, "Medsize" : 2, "Large" : 3}).astype(int)

# %%
categoricals["location_code"] = categoricals["location_code"].map({"Rural" : 1, "Suburban" : 2, "Urban" : 3}).astype(int)

# %%
categoricals['employmentstatus'].value_counts()
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64

# %%
categoricals['employmentstatus'] = categoricals['employmentstatus'].apply(lambda x: x if x in ['Employed', 'Unemployed'] else 'Other')

categoricals['employmentstatus'].value_counts()
# Out:
# Employed      5698
# Unemployed    2317
# Other         1119
# Name: employmentstatus, dtype: int64

# %%
categoricals["employmentstatus"] = categoricals["employmentstatus"].map({"Other" : 0, "Unemployed" : 1, "Employed" : 2}).astype(int)

# %%
categoricals_new = categoricals.select_dtypes('object')
categoricals_new.head()
# Out:
#         state response education gender marital_status     policy_type  \
# 0  Washington       No  Bachelor      F        Married  Corporate Auto
# 1     Arizona       No  Bachelor      F         Single   Personal Auto
# 2      Nevada       No  Bachelor      F        Married   Personal Auto
# 3  California       No  Bachelor      M        Married  Corporate Auto
# 4  Washington       No  Bachelor      M         Single   Personal Auto
#
#          policy renew_offer_type sales_channel  vehicle_class
# 0  Corporate L3           Offer1         Agent   Two-Door Car
# 1   Personal L3           Offer3         Agent  Four-Door Car
# 2   Personal L3           Offer1         Agent   Two-Door Car
# 3  Corporate L2           Offer1   Call Center            SUV
# 4   Personal L1           Offer1         Agent  Four-Door Car

# %% [raw]
# We have too many categories in the 'employmentstatus' column xe can bucketed several of them into one. We can also encode the 'coverage', 'vehicle_size' ,and 'location_code' columns.

# %%
data_crosstab1 = pd.crosstab(categoricals_new['education'], categoricals_new['marital_status'], margins=True)
data_crosstab1
# Out:
# marital_status        Divorced  Married  Single   All
# education
# Bachelor                   456     1550     742  2748
# College                    394     1550     737  2681
# Doctor                      60      238      44   342
# High School or Below       317     1489     816  2622
# Master                     142      471     128   741
# All                       1369     5298    2467  9134

# %%
from scipy.stats import chi2_contingency

stats, p_value, dof, frequencies = chi2_contingency(data_crosstab1)
p_value
# Out:
# 8.60830558013726e-17

# %%
data_crosstab2 = pd.crosstab(categoricals_new['renew_offer_type'], categoricals_new['sales_channel'], margins=True)
data_crosstab2
# Out:
# sales_channel     Agent  Branch  Call Center   Web   All
# renew_offer_type
# Offer1             1690    1099          588   375  3752
# Offer2              978     788          647   513  2926
# Offer3              518     394          291   229  1432
# Offer4              291     286          239   208  1024
# All                3477    2567         1765  1325  9134

# %%
stats, p_value, dof, frequencies = chi2_contingency(data_crosstab2)
p_value
# Out:
# 1.187207219148588e-41

# %% [raw]
# p_value below 0.05, we can drop one of the columns without decreasing the metrics of the model

# %%
categoricals_new = categoricals_new.drop(['sales_channel', 'marital_status'], axis=1)
categoricals_new
# Out:
#            state response education gender     policy_type        policy  \
# 0     Washington       No  Bachelor      F  Corporate Auto  Corporate L3
# 1        Arizona       No  Bachelor      F   Personal Auto   Personal L3
# 2         Nevada       No  Bachelor      F   Personal Auto   Personal L3
# 3     California       No  Bachelor      M  Corporate Auto  Corporate L2
# 4     Washington       No  Bachelor      M   Personal Auto   Personal L1
# ...          ...      ...       ...    ...             ...           ...
# 9129  California       No  Bachelor      M   Personal Auto   Personal L1
# 9130  California      Yes   College      F  Corporate Auto  Corporate L3
# 9131  California       No  Bachelor      M  Corporate Auto  Corporate L2
# 9132  California       No   College      M   Personal Auto   Personal L2
# 9133  California       No   College      M  Corporate Auto  Corporate L3
#
#      renew_offer_type  vehicle_class
# 0              Offer1   Two-Door Car
# ...

# %% [markdown]
# # Plot time variable. Can you extract something from it?

# %%
data["Dayweek"] = data["effective_to_date"].apply(lambda x: x.weekday())
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
data["Month"] = data["effective_to_date"].apply(lambda x: x.month)
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
sns.distplot(data['Dayweek'])
plt.show()

# %% [markdown]
# # We will start with removing outliers.

# %%
for column in data.select_dtypes(np.number).columns:
    sns.distplot(data[column])
    plt.show()

# %%
sns.boxplot(data['total_claim_amount'])
plt.show()

# %%
data[data['total_claim_amount'] < 1700]
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %% [markdown]
# # Create a copy of the dataframe for the data wrangling

# %%
log_transform = lambda x: np.log(x) if np.isfinite(x) and x != 0 else np.NAN

# %%
data1 = data.copy()

data1['total_claim_amount'] = data1['total_claim_amount'].apply(log_transform).fillna(data1['total_claim_amount'].mean())

# %%
sns.distplot(data1['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Density'>

# %%
data.corr()['total_claim_amount'].sort_values()
# Out:
# income                          -0.355254
# number_of_open_complaints       -0.014241
# number_of_policies              -0.002354
# months_since_policy_inception    0.003335
# Dayweek                          0.004977
# Month                            0.006820
# months_since_last_claim          0.007563
# customer_lifetime_value          0.226451
# monthly_premium_auto             0.632017
# total_claim_amount               1.000000
# Name: total_claim_amount, dtype: float64

# %%
data1.corr()['total_claim_amount'].sort_values()
# Out:
# income                          -0.339738
# number_of_open_complaints       -0.009333
# months_since_last_claim         -0.006746
# months_since_policy_inception   -0.002595
# Month                           -0.001512
# number_of_policies               0.002732
# Dayweek                          0.003729
# customer_lifetime_value          0.139258
# monthly_premium_auto             0.374490
# total_claim_amount               1.000000
# Name: total_claim_amount, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = data.drop('total_claim_amount', axis=1)
y = data['total_claim_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

X_train_num = X_train.select_dtypes(np.number)
X_test_num = X_test.select_dtypes(np.number)

# %% [markdown]
# # Normalize the continuous variables.

# %%
from sklearn.preprocessing import MinMaxScaler

numericals = data.select_dtypes(np.number)

transformer = MinMaxScaler().fit(numericals)
x_min_max = transformer.transform(numericals)
x_min_max
# Out:
# array([[0.01062925, 0.56284694, 0.03375527, ..., 0.13297388, 0.5       ,
#         1.        ],
#        [0.06240565, 0.        , 0.13924051, ..., 0.39105113, 0.        ,
#         0.        ],
#        [0.13495982, 0.48776267, 0.19831224, ..., 0.19576416, 0.83333333,
#         1.        ],
#        ...,
#        [0.07695057, 0.        , 0.10126582, ..., 0.27329676, 1.        ,
#         1.        ],
#        [0.06909758, 0.2194517 , 0.14767932, ..., 0.2388757 , 0.5       ,
#         1.        ],
#        [0.00876645, 0.        , 0.06751055, ..., 0.12771622, 0.        ,
#         1.        ]])

# %% [markdown]
# # Encode the categorical variables

# %%
categoricals = data.select_dtypes('object')
categoricals.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# ...

# %%
data["coverage"] = data["coverage"].map({"Basic" : 0, "Extended" : 1, "Premium" : 2})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coverage'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for column in categoricals.columns:
    print(data[column].value_counts())
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
# No     7826
# Yes    1308
# Name: response, dtype: int64
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
# F    4658
# M    4476
# Name: gender, dtype: int64
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
# Married     5298
# Single      2467
# Divorced    1369
# Name: marital_status, dtype: int64
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: policy_type, dtype: int64
# Personal L3     3426
# ...

# %%
data['employmentstatus'].value_counts()
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64

# %%
data['employmentstatus'] = data['employmentstatus'].apply(lambda x: x if x in ['Employed', 'Unemployed'] else 'Other')

data['employmentstatus'].value_counts()
# Out:
# Employed      5698
# Unemployed    2317
# Other         1119
# Name: employmentstatus, dtype: int64

# %%
data['policy'].value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64

# %%
data['policy'] = data['policy'].apply(lambda x: 'Special' if x in ['Special L3','Special L2','Special L1'] else x)

data['policy'].value_counts()
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Special          378
# Corporate L1     359
# Name: policy, dtype: int64

# %%
data['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: vehicle_class, dtype: int64

# %%
data['vehicle_class'] = data['vehicle_class'].apply(lambda x: 'Luxury' if x in ['Luxury SUV', 'Luxury Car'] else x)

data['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury            347
# Name: vehicle_class, dtype: int64

# %%
data.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0  Washington              2763.519279       No     Basic  Bachelor
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-24         Employed      F   56274      Suburban
# 1        2011-01-31       Unemployed      F       0      Suburban
# 2        2011-02-19         Employed      F   48767      Suburban
# 3        2011-01-20       Unemployed      M       0      Suburban
# 4        2011-02-03         Employed      M   43836         Rural
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    69                       32
# ...

# %% [markdown]
# # The time variable can be useful. Try to transform its data into a useful one.

# %%
data["Dayweek"] = data["effective_to_date"].apply(lambda x: x.weekday())
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %%
data["Month"] = data["effective_to_date"].apply(lambda x: x.month)
data
# Out:
#            state  customer_lifetime_value response  coverage education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      effective_to_date employmentstatus gender  income location_code  \
# ...

# %% [markdown]
# # Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.

# %%
categoricals = data.select_dtypes('object')
categoricals.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# ...

# %%
data = pd.get_dummies(data)
data
# Out:
#       customer_lifetime_value effective_to_date  income  monthly_premium_auto  \
# 0                 2763.519279        2011-02-24   56274                    69
# 1                 6979.535903        2011-01-31       0                    94
# 2                12887.431650        2011-02-19   48767                   108
# 3                 7645.861827        2011-01-20       0                   106
# 4                 2813.692575        2011-02-03   43836                    73
# ...                       ...               ...     ...                   ...
# 9129             23405.987980        2011-02-10   71941                    73
# 9130              3096.511217        2011-02-12   21604                    79
# 9131              8163.890428        2011-02-06       0                    85
# 9132              7524.442436        2011-02-03   21941                    96
# 9133              2611.836866        2011-02-14       0                    77
#
# ...
